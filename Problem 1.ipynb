# %%
def sumOfMultiples(n):
    sum = 0
    for i in range(n):
        if i % 3 == 0:
            sum += i
        elif i % 5 == 0:
            sum+= i
    return sum

# %%
sumOfMultiples(1000)
# Out:
# 233168
